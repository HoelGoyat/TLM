# %% [markdown]
# # Imports

# %%
import torchvision
from PIL import Image

# %%
resnet50 = torchvision.models.resnet50(pretrained=True)
with Image.open("rooster.jpg") as rooster:
    rooster.rotate(45).show()
# Out:
# <PIL.Image.Image image mode=RGB size=598x600>
